# %%
import numpy as np # tinh toan ma tran dai so
import pandas as pd # tien xử lý dữ liệu, được đọc vào input output
import matplotlib.pyplot as plt #nhiem vu la ve ra biểu đồ lượt đồ
import os # nhiệm vụ là đọc file , ghi file,ghi xuống ổ đĩa, thư mục,..
import cv2 # hàm xử lý thị giác máy tính
from sklearn.model_selection import train_test_split # chia ra 2 tập 1 huấn luyện 1 test
from keras.models import Sequential # khai báo tính tuần tự của mạng
from keras.layers import Dense, Dropout,Activation,Flatten #activation: là hàm kích hoạt, Dropout: chia nhỏ, Flatten: làm phẳng các hình 2D, 3D => tính toán các đặc trung qua cac tầng
from keras.layers import Convolution2D, MaxPooling2D #trích đặc trưng
import tensorflow as tf
from tensorflow.keras import utils #chứa hàm xử lý thông tin

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/TGMT/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TGMT

# %%
import pickle
# Ham doc anh tu file .data
def load_data():
  file = open('data.data', 'rb')

  # Load thong tin trong file .data
  (pixels, label_ids) = pickle.load(file)

  file.close()

  print(pixels.shape)
  print(label_ids.shape)

  return pixels, label_ids

data, labels = load_data()
# Out:
# (5250, 128, 128, 3)
# (5250, 46)

# %%
(trainX,testX,trainY,testY) = train_test_split(data,labels,test_size=0.2,random_state=42)

# %%
class_names = []

# Mở tệp labels.csv và đọc các mô tả lớp
with open('label.csv', 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines:
        parts = line.split(';')
        class_name = parts[1].strip()  # Mô tả lớp là phần tử thứ hai sau dấu chấm phẩy
        class_names.append(class_name)

print(class_names)
# Out:
# ['Không phải biển báo', 'Cấm đi ngược chiều', 'Cấm ô tô', 'Hạn chế tọng lượng xe', 'Hạn chế trọng lượng trên trục xe', 'Hạn chế chiều cao', 'Dừng lại', 'Cấm rẽ trái', 'Cấm rẽ phải', 'Tốc độ tối đa cho phép', 'Cấm dừng xe và đỗ xe', 'Cấm đỗ xe', 'Chỗ ngoặc nguy hiểm vòng bên trái', 'Chỗ ngoặc nguy hiểm vòng bên phải', 'Nhiều chỗ ngoặc nguy hiểm liên tiếp', 'Nhiều chỗ ngoặc nguy hiểm liên tiếp', 'Đường hẹp về cả hai bên', 'Đường hẹp về phía bên phải', 'Đường giao nhau cùng cấp', 'Đường giao nhau cùng cấp', 'Đường giao nhau cùng cấp', 'Đường giao nhau cùng cấp', 'Giao nhau chạy theo vòng xuyến', 'Giao nhau với đường không ưu tiên', 'Giao nhau với đường không ưu tiên', 'Giao nhau với đường không ưu tiên', 'Giao nhau với đường không ưu tiên', 'Giao nhau với đường không ưu tiên', 'Giao nhau với đường ưu tiên', 'Giao nhau có tín hiệu đèn', 'Cầu hẹp', 'Đường có ổ gà, lồi lõm', 'Đường người đi bộ cắt ngang', 'Trẻ em', 'Công trường', 'Nguy hiểm khác', 'Đi chậm', 'Chú ý xe đỗ', 'Nơi giao nhau chạy theo vòng xuyến', 'Chỗ quay xe', 'Chỉ hướng đường', 'Đường người đi bộ sang ngang', 'Bệnh viện', 'Bến xe buýt', 'Bến xe điện', 'Tên cầu']

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Flatten, Dense
from tensorflow.keras.models import Sequential

# Thiết lập mô hình InceptionV3
print("[INFO] compiling model.....")
InceptionV3_base = InceptionV3(input_shape=(128, 128, 3), include_top=False, weights='imagenet')
for layer in InceptionV3_base.layers:
    layer.trainable = False

model = Sequential()
model.add(InceptionV3_base)

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(len(class_names), activation='softmax'))

# Compile mô hình
EPOCHS =200   # 1000 ảnh 120-250
INIT_LR = 1e-3
BS = 32
opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

model.summary()
# Out:
# [INFO] compiling model.....
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2, 2, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 46)                94254
#
# =================================================================
# Total params: 21897038 (83.53 MB)
# Trainable params: 94254 (368.18 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
model.fit(trainX, trainY, batch_size=BS, epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/200
# 132/132 [==============================] - 16s 39ms/step - loss: 3.7142 - accuracy: 0.2921
# Epoch 2/200
# 132/132 [==============================] - 4s 31ms/step - loss: 1.6764 - accuracy: 0.5850
# Epoch 3/200
# 132/132 [==============================] - 4s 28ms/step - loss: 1.1875 - accuracy: 0.6869
# Epoch 4/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.9774 - accuracy: 0.7279
# Epoch 5/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.7427 - accuracy: 0.7898
# Epoch 6/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.6080 - accuracy: 0.8136
# Epoch 7/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.5616 - accuracy: 0.8379
# Epoch 8/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.5338 - accuracy: 0.8369
# Epoch 9/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.4575 - accuracy: 0.8595
# Epoch 10/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.4196 - accuracy: 0.8738
# Epoch 11/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.3852 - accuracy: 0.8771
# Epoch 12/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.3910 - accuracy: 0.8774
# Epoch 13/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.3759 - accuracy: 0.8829
# Epoch 14/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.3159 - accuracy: 0.8950
# Epoch 15/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.3300 - accuracy: 0.8981
# Epoch 16/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.3196 - accuracy: 0.8995
# Epoch 17/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.3255 - accuracy: 0.9005
# Epoch 18/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.3069 - accuracy: 0.9076
# Epoch 19/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2993 - accuracy: 0.9038
# Epoch 20/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2846 - accuracy: 0.9133
# Epoch 21/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2744 - accuracy: 0.9129
# Epoch 22/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2817 - accuracy: 0.9152
# Epoch 23/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2641 - accuracy: 0.9131
# Epoch 24/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2608 - accuracy: 0.9188
# Epoch 25/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2555 - accuracy: 0.9217
# Epoch 26/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2693 - accuracy: 0.9198
# Epoch 27/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2508 - accuracy: 0.9190
# Epoch 28/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2627 - accuracy: 0.9174
# Epoch 29/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2782 - accuracy: 0.9160
# Epoch 30/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2610 - accuracy: 0.9214
# Epoch 31/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2606 - accuracy: 0.9179
# Epoch 32/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2404 - accuracy: 0.9200
# Epoch 33/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2585 - accuracy: 0.9255
# Epoch 34/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2566 - accuracy: 0.9243
# Epoch 35/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2385 - accuracy: 0.9340
# Epoch 36/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2510 - accuracy: 0.9286
# Epoch 37/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2712 - accuracy: 0.9205
# Epoch 38/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2522 - accuracy: 0.9276
# Epoch 39/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2173 - accuracy: 0.9333
# Epoch 40/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2325 - accuracy: 0.9312
# Epoch 41/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2415 - accuracy: 0.9252
# Epoch 42/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2508 - accuracy: 0.9267
# Epoch 43/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2523 - accuracy: 0.9257
# Epoch 44/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2521 - accuracy: 0.9302
# Epoch 45/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2086 - accuracy: 0.9317
# Epoch 46/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2587 - accuracy: 0.9288
# Epoch 47/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2646 - accuracy: 0.9281
# Epoch 48/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2502 - accuracy: 0.9293
# Epoch 49/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2192 - accuracy: 0.9343
# Epoch 50/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2360 - accuracy: 0.9310
# Epoch 51/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2624 - accuracy: 0.9269
# Epoch 52/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2517 - accuracy: 0.9260
# Epoch 53/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2401 - accuracy: 0.9326
# Epoch 54/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2398 - accuracy: 0.9336
# Epoch 55/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2263 - accuracy: 0.9355
# Epoch 56/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2270 - accuracy: 0.9329
# Epoch 57/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2477 - accuracy: 0.9314
# Epoch 58/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2348 - accuracy: 0.9319
# Epoch 59/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2069 - accuracy: 0.9400
# Epoch 60/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2431 - accuracy: 0.9333
# Epoch 61/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2216 - accuracy: 0.9336
# Epoch 62/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2623 - accuracy: 0.9343
# Epoch 63/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2338 - accuracy: 0.9350
# Epoch 64/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2448 - accuracy: 0.9312
# Epoch 65/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2210 - accuracy: 0.9452
# Epoch 66/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2117 - accuracy: 0.9402
# Epoch 67/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2238 - accuracy: 0.9412
# Epoch 68/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2381 - accuracy: 0.9333
# Epoch 69/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1981 - accuracy: 0.9469
# Epoch 70/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2465 - accuracy: 0.9350
# Epoch 71/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1910 - accuracy: 0.9500
# Epoch 72/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2149 - accuracy: 0.9464
# Epoch 73/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2000 - accuracy: 0.9417
# Epoch 74/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2408 - accuracy: 0.9390
# Epoch 75/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2106 - accuracy: 0.9426
# Epoch 76/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2499 - accuracy: 0.9410
# Epoch 77/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2125 - accuracy: 0.9445
# Epoch 78/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2091 - accuracy: 0.9436
# Epoch 79/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2079 - accuracy: 0.9450
# Epoch 80/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2306 - accuracy: 0.9419
# Epoch 81/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2173 - accuracy: 0.9424
# Epoch 82/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2267 - accuracy: 0.9417
# Epoch 83/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1934 - accuracy: 0.9474
# Epoch 84/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2124 - accuracy: 0.9426
# Epoch 85/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2225 - accuracy: 0.9386
# Epoch 86/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2527 - accuracy: 0.9355
# Epoch 87/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2245 - accuracy: 0.9436
# Epoch 88/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2187 - accuracy: 0.9450
# Epoch 89/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2099 - accuracy: 0.9448
# Epoch 90/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2542 - accuracy: 0.9364
# Epoch 91/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2292 - accuracy: 0.9390
# Epoch 92/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2281 - accuracy: 0.9471
# Epoch 93/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1893 - accuracy: 0.9476
# Epoch 94/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1957 - accuracy: 0.9486
# Epoch 95/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2305 - accuracy: 0.9400
# Epoch 96/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2075 - accuracy: 0.9421
# Epoch 97/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2385 - accuracy: 0.9398
# Epoch 98/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2555 - accuracy: 0.9348
# Epoch 99/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2210 - accuracy: 0.9452
# Epoch 100/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2174 - accuracy: 0.9438
# Epoch 101/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2164 - accuracy: 0.9460
# Epoch 102/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2499 - accuracy: 0.9376
# Epoch 103/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2043 - accuracy: 0.9462
# Epoch 104/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2090 - accuracy: 0.9462
# Epoch 105/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2050 - accuracy: 0.9471
# Epoch 106/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2065 - accuracy: 0.9467
# Epoch 107/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2023 - accuracy: 0.9460
# Epoch 108/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.1772 - accuracy: 0.9521
# Epoch 109/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2144 - accuracy: 0.9455
# Epoch 110/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1882 - accuracy: 0.9540
# Epoch 111/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2388 - accuracy: 0.9452
# Epoch 112/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2156 - accuracy: 0.9460
# Epoch 113/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2221 - accuracy: 0.9460
# Epoch 114/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2209 - accuracy: 0.9424
# Epoch 115/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1922 - accuracy: 0.9519
# Epoch 116/200
# 132/132 [==============================] - 4s 33ms/step - loss: 0.1981 - accuracy: 0.9490
# Epoch 117/200
# 132/132 [==============================] - 5s 35ms/step - loss: 0.2253 - accuracy: 0.9455
# Epoch 118/200
# 132/132 [==============================] - 5s 38ms/step - loss: 0.2274 - accuracy: 0.9448
# Epoch 119/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2055 - accuracy: 0.9462
# Epoch 120/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1795 - accuracy: 0.9512
# Epoch 121/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2275 - accuracy: 0.9486
# Epoch 122/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2274 - accuracy: 0.9445
# Epoch 123/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2096 - accuracy: 0.9493
# Epoch 124/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1973 - accuracy: 0.9517
# Epoch 125/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.1838 - accuracy: 0.9548
# Epoch 126/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1929 - accuracy: 0.9533
# Epoch 127/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2377 - accuracy: 0.9481
# Epoch 128/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2071 - accuracy: 0.9486
# Epoch 129/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2149 - accuracy: 0.9452
# Epoch 130/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2388 - accuracy: 0.9462
# Epoch 131/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2100 - accuracy: 0.9448
# Epoch 132/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1978 - accuracy: 0.9493
# Epoch 133/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1744 - accuracy: 0.9545
# Epoch 134/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2127 - accuracy: 0.9457
# Epoch 135/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1968 - accuracy: 0.9526
# Epoch 136/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2094 - accuracy: 0.9462
# Epoch 137/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2025 - accuracy: 0.9519
# Epoch 138/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2090 - accuracy: 0.9505
# Epoch 139/200
# 132/132 [==============================] - 5s 38ms/step - loss: 0.2234 - accuracy: 0.9507
# Epoch 140/200
# 132/132 [==============================] - 5s 39ms/step - loss: 0.1943 - accuracy: 0.9502
# Epoch 141/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1846 - accuracy: 0.9524
# Epoch 142/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1962 - accuracy: 0.9524
# Epoch 143/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1643 - accuracy: 0.9593
# Epoch 144/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1840 - accuracy: 0.9538
# Epoch 145/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2410 - accuracy: 0.9474
# Epoch 146/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1849 - accuracy: 0.9579
# Epoch 147/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2410 - accuracy: 0.9436
# Epoch 148/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2133 - accuracy: 0.9486
# Epoch 149/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2029 - accuracy: 0.9519
# Epoch 150/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2139 - accuracy: 0.9498
# Epoch 151/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1939 - accuracy: 0.9490
# Epoch 152/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2372 - accuracy: 0.9495
# Epoch 153/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2128 - accuracy: 0.9507
# Epoch 154/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1936 - accuracy: 0.9529
# Epoch 155/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1939 - accuracy: 0.9552
# Epoch 156/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2119 - accuracy: 0.9514
# Epoch 157/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1887 - accuracy: 0.9562
# Epoch 158/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2179 - accuracy: 0.9490
# Epoch 159/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2223 - accuracy: 0.9486
# Epoch 160/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2323 - accuracy: 0.9514
# Epoch 161/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2395 - accuracy: 0.9448
# Epoch 162/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2477 - accuracy: 0.9433
# Epoch 163/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2146 - accuracy: 0.9479
# Epoch 164/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1973 - accuracy: 0.9529
# Epoch 165/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2235 - accuracy: 0.9481
# Epoch 166/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2065 - accuracy: 0.9510
# Epoch 167/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.1954 - accuracy: 0.9526
# Epoch 168/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1844 - accuracy: 0.9550
# Epoch 169/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1956 - accuracy: 0.9560
# Epoch 170/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2030 - accuracy: 0.9519
# Epoch 171/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2048 - accuracy: 0.9550
# Epoch 172/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2123 - accuracy: 0.9548
# Epoch 173/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2049 - accuracy: 0.9519
# Epoch 174/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2374 - accuracy: 0.9481
# Epoch 175/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2158 - accuracy: 0.9486
# Epoch 176/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1934 - accuracy: 0.9571
# Epoch 177/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2295 - accuracy: 0.9531
# Epoch 178/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2201 - accuracy: 0.9505
# Epoch 179/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2278 - accuracy: 0.9507
# Epoch 180/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1579 - accuracy: 0.9598
# Epoch 181/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2557 - accuracy: 0.9476
# Epoch 182/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2426 - accuracy: 0.9414
# Epoch 183/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1874 - accuracy: 0.9629
# Epoch 184/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2198 - accuracy: 0.9521
# Epoch 185/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2079 - accuracy: 0.9533
# Epoch 186/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1787 - accuracy: 0.9607
# Epoch 187/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1938 - accuracy: 0.9531
# Epoch 188/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1913 - accuracy: 0.9538
# Epoch 189/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.2222 - accuracy: 0.9543
# Epoch 190/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.1985 - accuracy: 0.9519
# Epoch 191/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2347 - accuracy: 0.9469
# Epoch 192/200
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2268 - accuracy: 0.9514
# Epoch 193/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2152 - accuracy: 0.9529
# Epoch 194/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2106 - accuracy: 0.9526
# Epoch 195/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1993 - accuracy: 0.9571
# Epoch 196/200
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1982 - accuracy: 0.9548
# Epoch 197/200
# 132/132 [==============================] - 4s 28ms/step - loss: 0.2081 - accuracy: 0.9555
# Epoch 198/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.2064 - accuracy: 0.9562
# Epoch 199/200
# 132/132 [==============================] - 4s 32ms/step - loss: 0.2308 - accuracy: 0.9517
# Epoch 200/200
# 132/132 [==============================] - 4s 29ms/step - loss: 0.1754 - accuracy: 0.9595

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# Dự đoán trên dữ liệu kiểm tra
pred = model.predict(testX)
predictions = np.argmax(pred, axis=1)

# Tính ma trận nhầm lẫn
cm = confusion_matrix(np.argmax(testY, axis=1), predictions)

# Vẽ biểu đồ ma trận nhầm lẫn
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Model confusion matrix')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)

# Hiển thị số liệu trên từng ô của ma trận nhầm lẫn
for i in range(len(class_names)):
    for j in range(len(class_names)):
        ax.text(i, j, cm[j, i], va='center', ha='center')

plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Tính độ chính xác
accuracy = accuracy_score(np.argmax(testY, axis=1), predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# Tính precision
precision = precision_score(np.argmax(testY, axis=1), predictions, average='weighted')
print("Precision: %.2f%%" % (precision * 100))

# Tính recall
recall = recall_score(np.argmax(testY, axis=1), predictions, average='weighted')
print("Recall: %.2f%%" % (recall * 100))

# Tính f1-score
f1 = f1_score(np.argmax(testY, axis=1), predictions, average='weighted')
print("F1-score: %.2f%%" % (f1 * 100))
# Out:
# 33/33 [==============================] - 1s 44ms/step
# <ipython-input-13-e5e8914aca99>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + class_names)
# <ipython-input-13-e5e8914aca99>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + class_names)
# Accuracy: 82.57%
# Precision: 84.21%
# Recall: 82.57%
# F1-score: 82.75%

# %%
# Lưu mô hình
model.save("interceptionV3.h5")
print("Mô hình đã được lưu thành công.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Mô hình đã được lưu thành công.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Đường dẫn của hình ảnh bạn muốn dự đoán
img_path = '/content/drive/MyDrive/TGMT/w205c.jpg'

# Load và tiền xử lý hình ảnh
img = image.load_img(img_path, target_size=(128, 128))
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = preprocess_input(img_batch)

# Dự đoán
pred = model.predict(img_preprocessed)
predicted_class_index = np.argmax(pred[0])
predicted_class = class_names[predicted_class_index]
confidence = pred[0][predicted_class_index] * 100

# Hiển thị hình ảnh và kết quả dự đoán
plt.imshow(img)
plt.text(10, 10, f"{predicted_class} ({confidence:.2f}%)", color="blue", fontsize="large", bbox=dict(fill=False, edgecolor='red', linewidth=1))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step
